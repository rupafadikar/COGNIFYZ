# %% [markdown]
# # Name : RUPA FADIKAR

# %% [markdown]
# # COGNIFYZ Internship Task : Business Analytics

# %% [markdown]
# # Task-3: Descriptive Statistics
# # Objective: Present basic statistics for numerical columns

# %%
import pandas as pd

# %%
# Load the dataset
df = pd.read_csv("Data_set 2 - Copy.csv")

# %%
# First 5 rows from Dataset
print("First 5 Rows :")
df.head(5)
# Out:
# First 5 Rows :
#    gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0  Female   34                Yes             1              2           5
# 1  Female   23                Yes             4              3           2
# 2    Male   30                Yes             3              6           4
# 3    Male   22                Yes             2              1           3
# 4  Female   24                 No             2              1           3
#
#    Government_Bonds  Fixed_Deposits  PPF  Gold  ...           Duration  \
# 0                 3               7    6     4  ...          1-3 years
# 1                 1               5    6     7  ...  More than 5 years
# 2                 2               5    1     7  ...          3-5 years
# 3                 7               6    4     5  ...   Less than 1 year
# 4                 6               4    5     7  ...   Less than 1 year
#
# ...

# %%
# 1.Identify Numerical Columns
numeric_columns = df.select_dtypes(include=['number'])
print("All Numeric columns :\n")
numeric_columns
# Out:
# All Numeric columns :
#     age  Mutual_Funds  Equity_Market  Debentures  Government_Bonds  \
# 0    34             1              2           5                 3
# 1    23             4              3           2                 1
# 2    30             3              6           4                 2
# 3    22             2              1           3                 7
# 4    24             2              1           3                 6
# 5    24             7              5           4                 6
# 6    27             3              6           4                 2
# 7    21             2              3           7                 4
# 8    35             2              4           7                 5
# 9    31             1              3           7                 4
# 10   35             2              4           7                 5
# 11   29             2              5           7                 6
# 12   21             1              2           3                 4
# ...

# %%
# Total numeric columns
count = len(df.select_dtypes(include=['number']).columns)
print("Total Numeric columns :",count)
# Out:
# Total Numeric columns : 8

# %%
# 2.Statistical Calculations
print("Statistical Calculations for each numerical column\n")
numeric_columns.describe()
# Out:
# Statistical Calculations for each numerical column
#              age  Mutual_Funds  Equity_Market  Debentures  Government_Bonds  \
# count  40.000000     40.000000      40.000000   40.000000         40.000000
# mean   27.800000      2.550000       3.475000    5.750000          4.650000
# std     3.560467      1.197219       1.131994    1.675617          1.369072
# min    21.000000      1.000000       1.000000    1.000000          1.000000
# 25%    25.750000      2.000000       3.000000    5.000000          4.000000
# 50%    27.000000      2.000000       4.000000    6.500000          5.000000
# 75%    30.000000      3.000000       4.000000    7.000000          5.000000
# max    35.000000      7.000000       6.000000    7.000000          7.000000
#
#        Fixed_Deposits        PPF       Gold
# count       40.000000  40.000000  40.000000
# mean         3.575000   2.025000   5.975000
# std          1.795828   1.609069   1.143263
# min          1.000000   1.000000   2.000000
# ...
