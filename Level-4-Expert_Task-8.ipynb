# %% [markdown]
# # Name : RUPA FADIKAR

# %% [markdown]
# # COGNIFYZ Internship Task : Business Analytics

# %% [markdown]
# # Task 8: Investment Duration
# # Objective: Calculate the average investment  duration

# %%
import pandas as pd

# %%
# Load the dataset
df = pd.read_csv("Data_set 2 - Copy.csv")

# %%
# First 5 rows from Dataset
print("First 5 Rows :")
df.head(5)
# Out:
# First 5 Rows :
#    gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0  Female   34                Yes             1              2           5
# 1  Female   23                Yes             4              3           2
# 2    Male   30                Yes             3              6           4
# 3    Male   22                Yes             2              1           3
# 4  Female   24                 No             2              1           3
#
#    Government_Bonds  Fixed_Deposits  PPF  Gold  ...           Duration  \
# 0                 3               7    6     4  ...          1-3 years
# 1                 1               5    6     7  ...  More than 5 years
# 2                 2               5    1     7  ...          3-5 years
# 3                 7               6    4     5  ...   Less than 1 year
# 4                 6               4    5     7  ...   Less than 1 year
#
# ...

# %%
# 1.Analyze Investment Duration Column
investment_duration = df['Duration'].value_counts()
investment_duration
# Out:
# Duration
# 3-5 years            19
# 1-3 years            18
# Less than 1 year      2
# More than 5 years     1
# Name: count, dtype: int64

# %%
# 2.Calculate Average Duration

# %%
# add numeric value according to duration because duration column is object type

duration_map = {
    "Less than 1 year": 0.5,
    "1-3 years": 2,
    "3-5 years": 4,
    "More than 5 years": 6 
}

df["Duration_Value"] = df["Duration"].map(duration_map)
df[["Duration", "Duration_Value"]]
# Out:
#              Duration  Duration_Value
# 0           1-3 years             2.0
# 1   More than 5 years             6.0
# 2           3-5 years             4.0
# 3    Less than 1 year             0.5
# 4    Less than 1 year             0.5
# 5           1-3 years             2.0
# 6           3-5 years             4.0
# 7           3-5 years             4.0
# 8           1-3 years             2.0
# 9           3-5 years             4.0
# 10          3-5 years             4.0
# 11          1-3 years             2.0
# 12          1-3 years             2.0
# 13          1-3 years             2.0
# 14          1-3 years             2.0
# 15          1-3 years             2.0
# 16          1-3 years             2.0
# 17          1-3 years             2.0
# 18          1-3 years             2.0
# 19          3-5 years             4.0
# 20          3-5 years             4.0
# 21          3-5 years             4.0
# 22          3-5 years             4.0
# 23          3-5 years             4.0
# ...

# %%
average_duration = df['Duration_Value'].mean()
print("The average investment duration :",average_duration)
# Out:
# The average investment duration : 2.975
