# %% [markdown]
# # Name : RUPA FADIKAR

# %% [markdown]
# # COGNIFYZ Internship Task : Business Analytics

# %% [markdown]
# # Task-10: Correlation Analysis
# #  Objective: Explore potential correlations  between factors

# %%
import pandas as pd

# %%
# Load the dataset
df = pd.read_csv("Data_set 2 - Copy.csv")

# %%
# First 5 rows from Dataset
print("First 5 Rows :")
df.head(5)
# Out:
# First 5 Rows :
#    gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0  Female   34                Yes             1              2           5
# 1  Female   23                Yes             4              3           2
# 2    Male   30                Yes             3              6           4
# 3    Male   22                Yes             2              1           3
# 4  Female   24                 No             2              1           3
#
#    Government_Bonds  Fixed_Deposits  PPF  Gold  ...           Duration  \
# 0                 3               7    6     4  ...          1-3 years
# 1                 1               5    6     7  ...  More than 5 years
# 2                 2               5    1     7  ...          3-5 years
# 3                 7               6    4     5  ...   Less than 1 year
# 4                 6               4    5     7  ...   Less than 1 year
#
# ...

# %%
# Add another column to define the except object datatype to numeric datatype column
e_return = {
    "20%-30%" : 2,
    "30%-40%" :  3,
    "10%-20%" :  1
}

df["Exp_Return"] = df["Expect"].map(e_return)
df[["Expect","Exp_Return"]]
# Out:
#      Expect  Exp_Return
# 0   20%-30%           2
# 1   20%-30%           2
# 2   20%-30%           2
# 3   10%-20%           1
# 4   20%-30%           2
# 5   30%-40%           3
# 6   20%-30%           2
# 7   20%-30%           2
# 8   20%-30%           2
# 9   30%-40%           3
# 10  20%-30%           2
# 11  20%-30%           2
# 12  20%-30%           2
# 13  20%-30%           2
# 14  20%-30%           2
# 15  20%-30%           2
# 16  20%-30%           2
# 17  20%-30%           2
# 18  20%-30%           2
# 19  20%-30%           2
# 20  20%-30%           2
# 21  20%-30%           2
# 22  20%-30%           2
# 23  20%-30%           2
# 24  30%-40%           3
# 25  20%-30%           2
# 26  20%-30%           2
# 27  20%-30%           2
# 28  20%-30%           2
# 29  10%-20%           1
# 30  10%-20%           1
# 31  20%-30%           2
# 32  30%-40%           3
# 33  20%-30%           2
# 34  20%-30%           2
# 35  20%-30%           2
# 36  20%-30%           2
# ...

# %%
# add numeric value according to duration because duration column is object type

duration_map = {
    "Less than 1 year": 0.5,
    "1-3 years": 2,
    "3-5 years": 4,
    "More than 5 years": 6 
}

df["Duration_Value"] = df["Duration"].map(duration_map)
df[["Duration", "Duration_Value"]]
# Out:
#              Duration  Duration_Value
# 0           1-3 years             2.0
# 1   More than 5 years             6.0
# 2           3-5 years             4.0
# 3    Less than 1 year             0.5
# 4    Less than 1 year             0.5
# 5           1-3 years             2.0
# 6           3-5 years             4.0
# 7           3-5 years             4.0
# 8           1-3 years             2.0
# 9           3-5 years             4.0
# 10          3-5 years             4.0
# 11          1-3 years             2.0
# 12          1-3 years             2.0
# 13          1-3 years             2.0
# 14          1-3 years             2.0
# 15          1-3 years             2.0
# 16          1-3 years             2.0
# 17          1-3 years             2.0
# 18          1-3 years             2.0
# 19          3-5 years             4.0
# 20          3-5 years             4.0
# 21          3-5 years             4.0
# 22          3-5 years             4.0
# 23          3-5 years             4.0
# ...

# %%
# 1.Select Relevant Columns
relevant_columns = df[['age', 'Duration_Value', 'Exp_Return']]
relevant_columns
# Out:
#     age  Duration_Value  Exp_Return
# 0    34             2.0           2
# 1    23             6.0           2
# 2    30             4.0           2
# 3    22             0.5           1
# 4    24             0.5           2
# 5    24             2.0           3
# 6    27             4.0           2
# 7    21             4.0           2
# 8    35             2.0           2
# 9    31             4.0           3
# 10   35             4.0           2
# 11   29             2.0           2
# 12   21             2.0           2
# 13   28             2.0           2
# 14   25             2.0           2
# 15   27             2.0           2
# 16   28             2.0           2
# 17   27             2.0           2
# 18   29             2.0           2
# 19   26             4.0           2
# 20   29             4.0           2
# 21   24             4.0           2
# 22   27             4.0           2
# 23   25             4.0           2
# 24   26             4.0           3
# ...

# %%
# Correlation between them
correlation = relevant_columns.corr()
print("Correlation :", correlation)
# Out:
# Correlation :                      age  Duration_Value  Exp_Return
# age             1.000000        0.051756   -0.089606
# Duration_Value  0.051756        1.000000    0.258223
# Exp_Return     -0.089606        0.258223    1.000000

# %%
# import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# %%
print("PAIRPLOT OF CORRELATION")
sns.pairplot(relevant_columns)
plt.show()
# Out:
# PAIRPLOT OF CORRELATION

# %%
print("SCATTER PLOT")
plt.figure(figsize=(6, 4))
sns.regplot(x=df["age"], y=df["Duration_Value"], scatter_kws={'alpha':0.5})
plt.title("Age vs Investment Duration")
plt.xlabel("Age")
plt.ylabel("Investment Duration (Years)")
plt.show()
# Out:
# SCATTER PLOT

# %%
print("SCATTER PLOT")
plt.figure(figsize=(6, 4))
sns.regplot(x=df["age"], y=df["Exp_Return"], scatter_kws={'alpha':0.5}, line_kws={"color":"red"})
plt.title("Age vs Expected Returns")
plt.xlabel("Age")
plt.ylabel("Expected Returns (%)")
plt.show()
# Out:
# SCATTER PLOT
